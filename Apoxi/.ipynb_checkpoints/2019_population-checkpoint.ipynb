# %%
import pandas as pd
import os
import numpy as np
import re
pd.set_option('display.max_rows', 100)
pd.__version__
# Out:
# '2.0.0'

# %%
def read_excel(filename):
    try:
        df = pd.read_excel(filename, header=1)
    except Exception as e:
        print(f"cannot read {filename}. Error: {e}")
    return df

# %%
def find_header_index(dataframe):
    value = 'ΣΥΝΟΛΟ TOTAL'
    indexes = []
    columns_to_check = dataframe.columns.tolist()
    for item in columns_to_check:
        idx = dataframe[dataframe[item].str.contains(value, na=False)].index #.tolist()
        indexes.append(idx)
        return indexes[0]

# %%
df = read_excel('A1605_SPO18_TS_AN_00_2001_00_2019_02_F_BI.xlsx')
df
# Out:
#       Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3
# 0            NaN         NaN         NaN         NaN  \
# 1            NaN         NaN         NaN         NaN
# 2            NaN         NaN         NaN         NaN
# 3            NaN         NaN         NaN         NaN
# 4            NaN         NaN         NaN         NaN
# 5            NaN         NaN         NaN         NaN
# 6          YEARS      2001.0      2002.0      2003.0
# 7   ΣΥΝΟΛΟ TOTAL  10862146.0  10902005.0  10928091.0
# 8            0-4    519933.0    535893.0    534723.0
# 9            5-9    533646.0    548524.0    542862.0
# 10         10-14    585027.0    616733.0    605800.0
# 11         15-19    694210.0    684291.0    660140.0
# 12         20-24    828909.0    816245.0    810580.0
# 13         25-29    862830.0    837543.0    839735.0
# 14         30-34    863177.0    858647.0    852735.0
# 15         35-39    767934.0    792564.0    813051.0
# 16         40-44    747828.0    758586.0    763355.0
# ...

# %%
idx = find_header_index(df)

# %%
value0 = idx[0]
value1 = idx[1]
value2 = idx[2]

# %%
column_names = df.iloc[(value0)-1].tolist()

# %%
df.columns = column_names

# %%
df[value0:(value1)-1]
# Out:
#            YEARS      2001.0      2002.0      2003.0      2004      2005
# 7   ΣΥΝΟΛΟ TOTAL  10862146.0  10902005.0  10928091.0  10955163  10987352  \
# 8            0-4    519933.0    535893.0    534723.0    532910    531198
# 9            5-9    533646.0    548524.0    542862.0    540406    538578
# 10         10-14    585027.0    616733.0    605800.0    590240    577259
# 11         15-19    694210.0    684291.0    660140.0    645447    636004
# 12         20-24    828909.0    816245.0    810580.0    795267    771972
# 13         25-29    862830.0    837543.0    839735.0    843587    847888
# 14         30-34    863177.0    858647.0    852735.0    847467    844327
# 15         35-39    767934.0    792564.0    813051.0    833206    849483
# 16         40-44    747828.0    758586.0    763355.0    765200    768910
# 17         45-49    695192.0    700108.0    713356.0    728801    741162
# 18         50-54    667999.0    660562.0    660602.0    663612    672027
# ...

# %%
df_all= df[value0:(value1)-1].reset_index(drop=True)
df_all = df_all.drop([19,20,21])
df_all
# Out:
#           NaN         2001.0      2002.0      2003.0    2004.0    2005.0
# 0   ΣΥΝΟΛΟ TOTAL  10862146.0  10902005.0  10928091.0  10955163  10987352  \
# 1            0-4    519933.0    535893.0    534723.0    532910    531198
# 2            5-9    533646.0    548524.0    542862.0    540406    538578
# 3          10-14    585027.0    616733.0    605800.0    590240    577259
# 4          15-19    694210.0    684291.0    660140.0    645447    636004
# 5          20-24    828909.0    816245.0    810580.0    795267    771972
# 6          25-29    862830.0    837543.0    839735.0    843587    847888
# 7          30-34    863177.0    858647.0    852735.0    847467    844327
# 8          35-39    767934.0    792564.0    813051.0    833206    849483
# 9          40-44    747828.0    758586.0    763355.0    765200    768910
# 10         45-49    695192.0    700108.0    713356.0    728801    741162
# 11         50-54    667999.0    660562.0    660602.0    663612    672027
# ...

# %%
column_names = df.iloc[(value1)-1].tolist()

# %%
df.columns = column_names

# %%
df_men = df[value1:(value2)-1].reset_index(drop=True)
df_men = df_men.drop([19,20,21])
df_men
# Out:
#           NaN        2001.0     2002.0     2003.0   2004.0   2005.0   2006.0
# 0   ΣΥΝΟΛΟ TOTAL  5355557.0  5387918.0  5400452.0  5412286  5425959  5437830  \
# 1            0-4   266808.0   274046.0   273617.0   272845   272138   272676
# 2            5-9   274204.0   279911.0   276960.0   275881   275068   274918
# 3          10-14   300368.0   316519.0   310933.0   302648   295850   288252
# 4          15-19   359728.0   358271.0   343838.0   334350   327582   322595
# 5          20-24   431824.0   425876.0   424282.0   417466   406318   391060
# 6          25-29   448426.0   433148.0   435353.0   438540   442155   442810
# 7          30-34   435392.0   434738.0   433641.0   432196   431261   431651
# 8          35-39   379419.0   395495.0   406476.0   417315   425886   431055
# 9          40-44   367488.0   374416.0   376409.0   377383   380076   385450
# 10         45-49   344763.0   347531.0   352911.0   359438   364443   367911
# ...

# %%
column_names = df.iloc[(value1)-1].tolist()

# %%
df.columns = column_names

# %%
df_wmn = df[value2:].reset_index(drop=True)
df_wmn
# Out:
#           NaN        2001.0     2002.0     2003.0   2004.0   2005.0   2006.0
# 0   ΣΥΝΟΛΟ TOTAL  5506589.0  5514087.0  5527639.0  5542877  5561393  5582563  \
# 1            0-4   253125.0   261847.0   261106.0   260065   259060   259470
# 2            5-9   259442.0   268613.0   265902.0   264525   263510   263025
# 3          10-14   284659.0   300214.0   294867.0   287592   281409   275153
# 4          15-19   334482.0   326020.0   316302.0   311097   308422   305930
# 5          20-24   397085.0   390369.0   386298.0   377801   365654   352284
# 6          25-29   414404.0   404395.0   404382.0   405047   405733   405808
# 7          30-34   427785.0   423909.0   419094.0   415271   413066   412195
# 8          35-39   388515.0   397069.0   406575.0   415891   423597   428158
# 9          40-44   380340.0   384170.0   386946.0   387817   388834   392309
# 10         45-49   350429.0   352577.0   360445.0   369363   376719   381922
# ...
